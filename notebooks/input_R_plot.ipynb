# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from Bio.Data import IUPACData
from collections import Counter

# %%
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.min_rows', 100)

# %%
classes_input  = pd.read_pickle('normalized/updated_2706/pathogenic_classes_input.pkl')

# %%
classes_labels  = pd.read_pickle('normalized/updated_2706/pathogenic_classes_labels.pkl')

# %%
classes_input.shape
# Out:
# (5528, 49)

# %%
classes_complete = pd.concat([classes_input, classes_labels], axis=1)

# %%
classes_complete.shape
# Out:
# (5528, 110)

# %%
classes_complete
# Out:
#        aliphatic_assign_WT  aromatic_assign_WT  hydrophobic_assign_WT  \
# 37                     0.0                 0.0                    0.0
# 52                     0.0                 0.0                    0.0
# 62                     0.0                 0.0                    0.0
# 63                     0.0                 0.0                    0.0
# 65                     0.0                 0.0                    0.0
# 67                     0.0                 0.0                    0.0
# 68                     0.0                 0.0                    0.0
# 69                     0.0                 0.0                    0.0
# 70                     1.0                 0.0                    1.0
# 71                     0.0                 0.0                    0.0
# 72                     0.0                 0.0                    0.0
# 73                     0.0                 0.0                    0.0
# ...

# %%
classes_complete.columns.to_list()
# Out:
# ['aliphatic_assign_WT',
#  'aromatic_assign_WT',
#  'hydrophobic_assign_WT',
#  'positive_assign_WT',
#  'negative_assign_WT',
#  'neutral_assign_WT',
#  'polar_assign_WT',
#  'special_assign_WT',
#  'aliphatic_assign_MUT',
#  'aromatic_assign_MUT',
#  'hydrophobic_assign_MUT',
#  'positive_assign_MUT',
#  'negative_assign_MUT',
#  'neutral_assign_MUT',
#  'polar_assign_MUT',
#  'special_assign_MUT',
#  'is_catalytic',
#  'Transmembrane_helices',
#  'Cleavage_site_(Signalp)',
#  'Conservation',
#  'pLDDT',
#  'number_of_contacts',
#  'BLOSUM62_nonNeg',
#  'total energy',
#  'Backbone Hbond',
#  'Sidechain Hbond',
#  'Van der Waals',
#  'Electrostatics',
#  'Solvation Polar',
#  'Solvation Hydrophobic',
#  'Van der Waals clashes',
#  'entropy sidechain',
#  'entropy mainchain',
#  'torsional clash',
#  'backbone clash',
#  'helix dipole',
#  'disulfide',
#  'energy Ionisation',
#  'ss3_H',
#  'ss3_E',
#  'ss3_C',
#  'acc_B',
#  'acc_M',
#  'acc_E',
#  'RSA',
#  'diso_score',
# ...

# %%
classes_complete['PANTHER'].isnull().sum()
# Out:
# 0

# %%
classes_complete['Pfam'].isnull().sum()
# Out:
# 0

# %%
classes_complete['PhenotypeClass'].value_counts()
# Out:
# [epileptic_encephalopathy]                                          1286
# [heart_disease]                                                      844
# [intellectual_disability]                                            786
# [cancer]                                                             653
# [heart_disease, marfan_syndrome]                                     520
# [hypercholesterolemia]                                               437
# [charcot-marie-tooth]                                                391
# [cancer, cancer]                                                     177
# [marfan_syndrome]                                                    127
# [heart_disease, hypercholesterolemia]                                 73
# [intellectual_disability, epileptic_encephalopathy]                   48
# [cancer, cancer, cancer]                                              39
# [heart_disease, cancer]                                               37
# ...
